# %%
import pandas as pd
final_df = []
for ratio in [0.25, 0.5, 0.75]:
    for dataset_name in ['atis', 'snips', 'clinc', 'stackoverflow', 'banking', 'mcid', 'reuters', 'thucnews' , 'linkedln', 'ele', 'news']:
        for seed in range(5):
            try:
                file_path = f"model_output/{dataset_name}_{ratio}_{seed}.csv"
                df = pd.read_csv(file_path)
                df = df[['METRIC', 'ACC_ALL', 'F1_ALL', 'F1_OOD', 'F1_IND']]
                df.columns = ['method', 'ACC', 'F1','N-F1', 'K-F1']
                for metric_name in ['ACC', 'F1', 'N-F1', 'K-F1']:
                    sub_df = df[['method', metric_name]]
                    sub_df['value'] = sub_df[metric_name]
                    sub_df['metric'] = metric_name
                    sub_df = sub_df.drop(metric_name, axis=1)
                    sub_df['seed'] = seed
                    sub_df['method'] = 'KNNCon_' + sub_df['method']
                    sub_df['dataset'] = dataset_name
                    sub_df['ratio'] = ratio
                    final_df.append(sub_df)
            except Exception as e:
                print()
final_df = pd.concat(final_df).drop_duplicates(['method','dataset','metric', 'ratio', 'seed'])
final_df = final_df.sort_values(['method','dataset','metric', 'seed'])
final_df.to_csv('../../table_results/raw/KNN_result.csv', index=None)
final_df
# Out:
# /tmp/ipykernel_550078/1642151781.py:13: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   sub_df['value'] = sub_df[metric_name]
# /tmp/ipykernel_550078/1642151781.py:14: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   sub_df['metric'] = metric_name
# /tmp/ipykernel_550078/1642151781.py:13: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# ...
